# %% [markdown]
# # Jupyter notebook features

# %% [markdown]
# General stuff
#
# - Launching
# - Shutting down
# - Path
#
# Command mode vs. Edit mode
#
# - Esc key
#
# Cell evaluation
#
# - Shift enter
#
# Cells
#
# -  Selecting
# -  Adding
# -  Deleting
# -  Moving cells
# -  Copy/Paste
#
# Cell types
#
# -  Markdown (M) https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
# -  Code (Y)
# -  Headings
#
# Bullets
#
# - This is
# - A test
#
#  - This is another test
#  - and another
#
# - And another
#     - test1
#     - test2
#
# Numbered lists/Outlines (use the tab key)
#
# 1. First entry
# 2. Second entry
#     1. Sub entry
#     2. Sub entry
#         1. Subsub entry 1
#         2. Subsub entry 2
#         3. Subsub entry 3
#     3. Sub entry
#
# Math via latex:
#
# $\int_{x=0}^\infty e^{-t} dt = 1$
#
# $y = \alpha + \beta x$
#
# $e^{\pi i} = -1$
#
# $x^2 - 1 = 0$
#
# Fonts
#
#     Bold: __string__ or **string**
#
# **this should be bold**
#
#     Italic: _string_ or *string*
#
# *this should be italicized*
#
# Indenting:
#
# >This should be indented
# >> This should be double-indented

# %% [markdown]
# $\int_{x=0}^t e^x dx$

# %% [markdown]
# # Toggling Line Numbers

# %% [raw]
# Sometimes we want to have line numbers in our code.  Using "l" in command mode allows us to turn line numbers on and off in a selected cell.

# %%
x=1
y=2
print(x)
print(y)

# %% [markdown]
# # Moving from Cell to Cell

# %% [markdown]
# Use j to move to the next cell and k to move to the previous cell.

# %%
x=5

# %%
a=4

# %% [markdown]
# # Heading 1
#
# Some text
#
# ## Heading 2
#
# Some more text
#
# ### Heading 3
#
# Even more test

# %% [markdown]
# # Images
#
#
# ![image.png](attachment:image.png)
